# %% [markdown]
# # Intro
#
# In this notebook, we explore a collection of ancient Akkadian and ancient Egyptian texts using the vector space model approach described by [Karsdorp et al. in the chapter "Exploring Texts using the Vector Space Model"](https://www.humanitiesdataanalysis.org/vector-space-model/notebook.html). By representing the texts as numeric vectors capturing word frequencies, we can quantify the lexical similarities and differences between corpora in each of these two ancient languages. The vector space model allows us to reason about texts spatially and apply geometric concepts like distance metrics to assess how "close" texts are to each other based on shared vocabulary.
#
# We preprocess the texts by tokenizing them into words, constructing a document-term matrix recording word frequencies per text, and analyzing the matrix using tools from the Python scientific computing stack, including NumPy, SciPy and Scikit-learn. Through techniques like tSNE (t-Distributed Stochastic Neighbor Embedding) and aggregation by text metadata like script type, language or genre, we explore patterns in the Akkadian and Egyptian corpora and showcase how the vector space model can yield quantitative insights into ancient textual data. The notebook serves as an example application of the concepts and methods covered in depth by Karsdorp et al. in their chapter.
#
# This notebook has been prepared by Avital Romach and is based on her research. It should be cited accordingly (see citation information at the bottom).

# %% [markdown]
# # Preprocessing the corpus

# %% [markdown]
# ## Imports

# %%
import os
import re
import numpy as np
import pandas as pd
import requests
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.spatial.distance import pdist, squareform
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import plotly.express as px

# %% [markdown]
# ## Functions

# %% [markdown]
# ### To upload corpus and metadata from GitHub

# %%
def create_corpus_from_github_api(url):
  # URL on the Github where the csv files are stored
  github_url = url
  response = requests.get(github_url)

  corpus = []
  # Check if the request was successful
  if response.status_code == 200:
    files = response.json()
    for file in files:
      if file["download_url"][-3:] == "csv":
        #corpus.append(pd.read_csv(file["download_url"], encoding="utf-8", index_col="Unnamed: 0").fillna(""))
        # For Egyptian adapt like this:
        corpus.append(pd.read_csv(file["download_url"], encoding="utf-8").fillna(""))
  else:
    print('Failed to retrieve files:', response.status_code)

  return corpus

def get_metadata_from_raw_github(url):
  metadata = pd.read_csv(url, encoding="utf-8", index_col="Unnamed: 0").fillna("")
  return metadata

# %%
# Prepare Akkadian corpus (list of dataframes)

#corpus = create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/rinap01')
#corpus.extend(create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/rinap05'))

# Prepare Egyptian corpus (list sof dataframes)
corpus = create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/TLA_pEbers')
corpus.extend(create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/TLA_pEdwinSmith'))

# %%
corpus[0].head()
# Out:
#                          text  \
# 0  5FTT5MPBHZC3HK4LCBHO5ILEQY
# 1  5FTT5MPBHZC3HK4LCBHO5ILEQY
# 2  5FTT5MPBHZC3HK4LCBHO5ILEQY
# 3  5FTT5MPBHZC3HK4LCBHO5ILEQY
# 4  5FTT5MPBHZC3HK4LCBHO5ILEQY
#
#                                            text_name  line  word  \
# 0  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     3
# 1  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     4
# 2  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     5
# 3  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     6
# 4  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     7
#
#                            ref    frag    norm unicode_original unicode_word  \
# 0  IBUBd7b7rdeJUUT0nty1mN1QWUM  ḥꜣ.t-ꜥ  ḥꜣ.t-ꜥ              𓄂𓐰𓂝           𓄂𓂝
# 1  IBkAd3TWR04hpEXUm7OiyMRF04s       m       m                𓅓            𓅓
# 2  IBUBd03k21v2k0dNtDvMsxLbqT0      rʾ      rʾ               𓂋𓏤           𓂋𓏤
# 3  IBUBdyzQkQqkHUDEtJYoxN3GjHE       n       n                𓈖            𓈖
# 4  IBUBdx1WBVRlPERaoRaCiwnroDo     wꜣḥ     wꜣḥ             𓎝𓎛𓑕𓏛         𓎝𓎛𓑕𓏛
#
#                          unicode  lemma_id      cf   pos mask  \
# 0                     ['𓄂', '𓂝']    853378  ḥꜣ.t-ꜥ  NOUN
# 1                          ['𓅓']    400082       m  PREP
# 2                     ['𓂋', '𓏤']     92580      rʾ  NOUN
# 3                          ['𓈖']     79800     n.ꞽ   ADJ
# 4  ['𓎝', '𓎛', '\U00013455', '𓏛']     43010     wꜣḥ  VERB
#
#                                                sense inst reading  break_perc  \
# 0      Anfang (von etwas, mit versch. Präpositionen)                 0.000000
# 1  in (der Art); von (partitiv); als (Eigenschaft...                 0.000000
# 2                                  Spruch; das Sagen                 0.000000
# 3                                      von [Genitiv]                 0.000000
# 4                legen; dauern; opfern; zurücklassen                 0.166667
#
#   unicode_splitted                                break
# 0       ['𓄂', '𓂝']             ['complete', 'complete']
# 1            ['𓅓']                         ['complete']
# 2       ['𓂋', '𓏤']             ['complete', 'complete']
# 3            ['𓈖']                         ['complete']
# 4  ['𓎝', '𓎛', '𓏛']  ['complete', 'damaged', 'complete']

# %%
# Prepare text_ids (list of unique ids), and metadata

text_ids = []
for text in corpus:
  text_ids.append(text["text"].iloc[0])

# Akkadian metadata
metadata = get_metadata_from_raw_github("https://raw.githubusercontent.com/DigitalPasts/ALP-course/master/course_notebooks/data/rinap1_5_metadata.csv")
# Egyptian metadata
metadata = get_metadata_from_raw_github("https://raw.githubusercontent.com/DigitalPasts/ALP-course/master/course_notebooks/data/TLA_metadata.csv")

for id in text_ids:
  if id not in metadata.index:
    print(f"Text {id} missing from metadata")

metadata = metadata[metadata.index.isin(text_ids)]

# %% [markdown]
# ### To convert dataframe to string

# %% [markdown]
# **Function to split the text dataframes according to a column**. Used to separate text to lines:
# * param df: dataframe containing one word in each row.
# * param column: the column by which to split the dfs, perferably `text` or `line`.
# * return: a list of dataframes split according to the value given to the column parameter.

# %%
def split_df_by_column_value(df, column):

    dfs = []
    column_values = df[column].unique()
    for value in column_values:
        split_df = df[df[column]==value]
        dfs.append(split_df)
    return dfs

# %%
split_df_by_column_value(corpus[0].head(), "line")
# Out:
# [                         text  \
#  0  5FTT5MPBHZC3HK4LCBHO5ILEQY
#  1  5FTT5MPBHZC3HK4LCBHO5ILEQY
#  2  5FTT5MPBHZC3HK4LCBHO5ILEQY
#  3  5FTT5MPBHZC3HK4LCBHO5ILEQY
#  4  5FTT5MPBHZC3HK4LCBHO5ILEQY
#
#                                             text_name  line  word  \
#  0  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     3
#  1  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     4
#  2  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     5
#  3  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     6
#  4  Medizinische Texte || pEbers || 1,1-2,6 = Eb 1...     1     7
#
#                             ref    frag    norm unicode_original unicode_word  \
#  0  IBUBd7b7rdeJUUT0nty1mN1QWUM  ḥꜣ.t-ꜥ  ḥꜣ.t-ꜥ              𓄂𓐰𓂝           𓄂𓂝
#  1  IBkAd3TWR04hpEXUm7OiyMRF04s       m       m                𓅓            𓅓
#  2  IBUBd03k21v2k0dNtDvMsxLbqT0      rʾ      rʾ               𓂋𓏤           𓂋𓏤
#  3  IBUBdyzQkQqkHUDEtJYoxN3GjHE       n       n                𓈖            𓈖
#  4  IBUBdx1WBVRlPERaoRaCiwnroDo     wꜣḥ     wꜣḥ             𓎝𓎛𓑕𓏛         𓎝𓎛𓑕𓏛
#
#                           unicode  lemma_id      cf   pos mask  \
#  0                     ['𓄂', '𓂝']    853378  ḥꜣ.t-ꜥ  NOUN
#  1                          ['𓅓']    400082       m  PREP
#  2                     ['𓂋', '𓏤']     92580      rʾ  NOUN
#  3                          ['𓈖']     79800     n.ꞽ   ADJ
#  4  ['𓎝', '𓎛', '\U00013455', '𓏛']     43010     wꜣḥ  VERB
#
#                                                 sense inst reading  break_perc  \
#  0      Anfang (von etwas, mit versch. Präpositionen)                 0.000000
#  1  in (der Art); von (partitiv); als (Eigenschaft...                 0.000000
#  2                                  Spruch; das Sagen                 0.000000
#  3                                      von [Genitiv]                 0.000000
#  4                legen; dauern; opfern; zurücklassen                 0.166667
#
#    unicode_splitted                                break
#  0       ['𓄂', '𓂝']             ['complete', 'complete']
#  1            ['𓅓']                         ['complete']
#  2       ['𓂋', '𓏤']             ['complete', 'complete']
#  3            ['𓈖']                         ['complete']
#  4  ['𓎝', '𓎛', '𓏛']  ['complete', 'damaged', 'complete']  ]

# %% [markdown]
# **Function to convert the values from the text dataframe to a string of text with or without line breaks and word segmentation**.
# * param df: the text dataframe
# * param column: the chosen column from the dataframe to construct the text from (preferably unicode_word, cf, or lemma)
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a string which includes all the words in the texts according to the column chosen. Extra spaces that were between broken words or empty lines are removed.

# %%
def df2str(df, column, break_perc=1, mask=True, segmentation=True):

    # check if column exists in dataframe. If not, return empty text.
    if column not in df.columns:
        return ("", 0, 0)
    else:
        # remove rows that include duplicate values for compound words
        if column not in ["norm", "cf", "sense", "pos"]:
            df = df.drop_duplicates("ref").copy()
        # if column entry is empty string, replace with UNK (can happen with normalization or lemmatization)
        mask_empty = df[column]==""
        df[column] = df[column].where(~mask_empty, other="UNK")
        # mask proper nouns
        if mask and "pos" in df.columns:
            mask_bool = df["pos"].isin(["PN", "RN", "DN", "GN", "MN", "SN", "n"])
            df[column] = df[column].where(~mask_bool, other=df["pos"])
        # change number masking from `n` to `NUM`
        # !comment out for Egyptian
        #if mask:
         #   mask_num = df[column]=="n"
          #  df[column] = df[column].where(~mask_num, other="NUM")
        # remove rows without break_perc (happens with non-Akkadian words)
        if "" in df["break_perc"].unique():
            df = df[df["break_perc"]!=""].copy()
        # filter according to break_perc
        mask_break = df["break_perc"] <= break_perc
        df[column] = df[column].where(mask_break, other="X")
        # calculate text length with and without UNK and x tokens
        text_length_full = df.shape[0]
        mask_partial = df[column].isin(["UNK", "X", "x"])
        text_length_partial = text_length_full - sum(mask_partial)
        # create text lines
        text = ""
        df_lines = split_df_by_column_value(df, "line")
        for line in df_lines:
            word_list = list(filter(None, line[column].to_list()))
            if word_list != []:
                text += " ".join(map(str, word_list)).replace("x", "X").strip() + "\n"

        if segmentation == False:
            # remove all white spaces (word segmentation and line breaks)
            text = re.sub(r"[\s\u00A0]+", "", text)

        return (text, text_length_full, text_length_partial)

# %%
df2str(corpus[0], "cf")
# Out:
# ('ḥꜣ.t-ꜥ m rʾ n.ꞽ wꜣḥ pẖr.t ḥr ꜥ.t nb n.ꞽ z\npri̯ ⸗ꞽ m Ꞽwn.w ḥnꜥ Wr.w-n.w-Ḥw.t-ꜥꜣ.t nb-mkw.t ḥqꜣ-nḥḥ\nnḥm.n pri̯ ⸗ꞽ m Zꜣw ḥnꜥ mw.t-nṯr\nrḏi̯ ⸗sn n ⸗ꞽ mkw.t ⸗sn\nꞽw ṯꜣz n ⸗ꞽ ꞽri̯ nb-r-ḏr r dr s.t-ꜥ nṯr nṯr.t mwt mwt.t ḥmw.t-rʾ n.tꞽ m tp ⸗ꞽ pn m nḥb.t ⸗ꞽ ꞽptn tn m qꜥḥ ⸗ꞽ ꞽpn m ꞽwf ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn r szwnu̯ srḫ.y ḥr.ꞽ sꜥq ẖnn.w m ꞽwf ⸗ꞽ pn bꞽbꞽ m ꜥ.t ⸗ꞽ ꞽptn m ꜥq m ꞽwf ⸗ꞽ pn m tp ⸗ꞽ pn m qꜥḥ ⸗ꞽ ꞽpn m ḥꜥ.w ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn\nn.ꞽ wꞽ Rꜥw ḏd ⸗f\nꞽnk nḏ ⸗ꞽ sw m-ꜥ ḫft.ꞽ ⸗f\nsšm.w ⸗f pw Ḏḥw.tꞽ\nꞽw ⸗f rḏi̯ ⸗f mdwi̯ drf\nꞽri̯ ⸗f dmḏ.t\nrḏi̯ ⸗f ꜣḫ.w n rḫ-ꞽḫ.t n zwn.w ꞽm.ꞽ-ḫt ⸗f r wḥꜥ mri̯ nṯr sꜥnḫ ⸗f sw\nꞽnk pw mri̯ nṯr sꜥnḫ ⸗f wꞽ\nḏd-mdw ḫft wꜣḥ pẖr.t ḥr ꜥ.t nb n.ꞽ z n.tꞽ mr\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\nky rʾ n.ꞽ wḥꜥ wt nb\nwḥꜥ zp ꞽn Ꜣs.t\nwḥꜥ Ḥr.w ꞽn Ꜣs.t m ḏw.t ꞽri̯ r ⸗f ꞽn sn ⸗f Stẖ m smꜣ ⸗f ꞽtꞽ ⸗f Wsꞽr\nꞽ Ꜣs.t wr.t-ḥkꜣ.w wḥꜥ ⸗ṯ wꞽ\nsfḫ ⸗ṯ wꞽ m-ꜥ ꞽḫ.t nb bꞽn ḏw dšr m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t m-ꜥ ḏꜣ.yw ḏꜣ.yt ḏꜣi̯ ⸗fꞽ sw m ⸗ꞽ mꞽ wḥꜥ ⸗ṯ mꞽ sfḫ ⸗ṯ m-ꜥ zꜣ ⸗ṯ Ḥr.w ḥr-n.tꞽt ꜥq ⸗ꞽ m ḫ.t pri̯ ⸗ꞽ m mw\nnn hꜣi̯ ⸗ꞽ r ꞽbṯ.t n.ꞽ hrw pn\nḏd ⸗ꞽ ḫ ḫꜣ\nꞽ Rꜥw mdwi̯ ḥr ḏ.t ⸗k\nWsꞽr sbḥ ḥr pri̯ m ⸗k\nmdwi̯ Rꜥw ḥr ḏ.t ⸗f\nsbḥ Wsꞽr ḥr pri̯ m ⸗f\nꞽsk nḥm ⸗k wꞽ m-ꜥ ꞽḫ.t nb bꞽn ḏw dšr m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t ḥmw.t-rʾ\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\nrʾ n.ꞽ zwr pẖr.t\nꞽwi̯ pẖr.t\nꞽwi̯ dr ꞽḫ.t m ꞽb ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn\nnḫt ḥkꜣ.w ḥr pẖr.t ṯꜣz-pẖr\nꞽn-ꞽw tr sḫꜣ ⸗k ꞽṯi̯ Ḥr.w ḥnꜥ Stẖ r ꞽz.t ꜥꜣ n.ꞽ Ꞽwn.w m nḏ ẖr.wꞽ Stẖ ḥnꜥ ꞽr.t Ḥr.w\nwn.ḫr ⸗f wꜣḏ mꞽ wnn ⸗f tp tꜣ\nꞽw ⸗f ꞽri̯ ⸗f mri̯ ⸗f nb mꞽ nw-n nṯr n.tꞽ ꞽm\nḏd-mdw ḫft zwr pẖr.t\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\n',
#  375,
#  375)

# %% [markdown]
# ### To convert to specific word levels and create dictionaries

# %% [markdown]
# **Function to convert the dataframes into strings of lemmatized texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the lemmatized texts

# %%
def get_lemmatized_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "cf", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_lemmatized_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'5FTT5MPBHZC3HK4LCBHO5ILEQY': ('ḥꜣ.t-ꜥ m rʾ n.ꞽ wꜣḥ pẖr.t ḥr ꜥ.t nb n.ꞽ z\npri̯ ⸗ꞽ m Ꞽwn.w ḥnꜥ Wr.w-n.w-Ḥw.t-ꜥꜣ.t nb-mkw.t ḥqꜣ-nḥḥ\nnḥm.n pri̯ ⸗ꞽ m Zꜣw ḥnꜥ mw.t-nṯr\nrḏi̯ ⸗sn n ⸗ꞽ mkw.t ⸗sn\nꞽw ṯꜣz n ⸗ꞽ ꞽri̯ nb-r-ḏr r dr s.t-ꜥ nṯr nṯr.t mwt mwt.t ḥmw.t-rʾ n.tꞽ m tp ⸗ꞽ pn m nḥb.t ⸗ꞽ ꞽptn tn m qꜥḥ ⸗ꞽ ꞽpn m ꞽwf ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn r szwnu̯ srḫ.y ḥr.ꞽ sꜥq ẖnn.w m ꞽwf ⸗ꞽ pn bꞽbꞽ m ꜥ.t ⸗ꞽ ꞽptn m ꜥq m ꞽwf ⸗ꞽ pn m tp ⸗ꞽ pn m qꜥḥ ⸗ꞽ ꞽpn m ḥꜥ.w ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn\nn.ꞽ wꞽ Rꜥw ḏd ⸗f\nꞽnk nḏ ⸗ꞽ sw m-ꜥ ḫft.ꞽ ⸗f\nsšm.w ⸗f pw Ḏḥw.tꞽ\nꞽw ⸗f rḏi̯ ⸗f mdwi̯ drf\nꞽri̯ ⸗f dmḏ.t\nrḏi̯ ⸗f ꜣḫ.w n rḫ-ꞽḫ.t n zwn.w ꞽm.ꞽ-ḫt ⸗f r wḥꜥ mri̯ nṯr sꜥnḫ ⸗f sw\nꞽnk pw mri̯ nṯr sꜥnḫ ⸗f wꞽ\nḏd-mdw ḫft wꜣḥ pẖr.t ḥr ꜥ.t nb n.ꞽ z n.tꞽ mr\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\nky rʾ n.ꞽ wḥꜥ wt nb\nwḥꜥ zp ꞽn Ꜣs.t\nwḥꜥ Ḥr.w ꞽn Ꜣs.t m ḏw.t ꞽri̯ r ⸗f ꞽn sn ⸗f Stẖ m smꜣ ⸗f ꞽtꞽ ⸗f Wsꞽr\nꞽ Ꜣs.t wr.t-ḥkꜣ.w wḥꜥ ⸗ṯ wꞽ\nsfḫ ⸗ṯ wꞽ m-ꜥ ꞽḫ.t nb bꞽn ḏw dšr m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t m-ꜥ ḏꜣ.yw ḏꜣ.yt ḏꜣi̯ ⸗fꞽ sw m ⸗ꞽ mꞽ wḥꜥ ⸗ṯ mꞽ sfḫ ⸗ṯ m-ꜥ zꜣ ⸗ṯ Ḥr.w ḥr-n.tꞽt ꜥq ⸗ꞽ m ḫ.t pri̯ ⸗ꞽ m mw\nnn hꜣi̯ ⸗ꞽ r ꞽbṯ.t n.ꞽ hrw pn\nḏd ⸗ꞽ ḫ ḫꜣ\nꞽ Rꜥw mdwi̯ ḥr ḏ.t ⸗k\nWsꞽr sbḥ ḥr pri̯ m ⸗k\nmdwi̯ Rꜥw ḥr ḏ.t ⸗f\nsbḥ Wsꞽr ḥr pri̯ m ⸗f\nꞽsk nḥm ⸗k wꞽ m-ꜥ ꞽḫ.t nb bꞽn ḏw dšr m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t ḥmw.t-rʾ\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\nrʾ n.ꞽ zwr pẖr.t\nꞽwi̯ pẖr.t\nꞽwi̯ dr ꞽḫ.t m ꞽb ⸗ꞽ pn m ꜥ.t ⸗ꞽ ꞽptn\nnḫt ḥkꜣ.w ḥr pẖr.t ṯꜣz-pẖr\nꞽn-ꞽw tr sḫꜣ ⸗k ꞽṯi̯ Ḥr.w ḥnꜥ Stẖ r ꞽz.t ꜥꜣ n.ꞽ Ꞽwn.w m nḏ ẖr.wꞽ Stẖ ḥnꜥ ꞽr.t Ḥr.w\nwn.ḫr ⸗f wꜣḏ mꞽ wnn ⸗f tp tꜣ\nꞽw ⸗f ꞽri̯ ⸗f mri̯ ⸗f nb mꞽ nw-n nṯr n.tꞽ ꞽm\nḏd-mdw ḫft zwr pẖr.t\nsšr-mꜣꜥ ḥḥ n.ꞽ zp\n',
#   375,
#   375)}

# %% [markdown]
# **Function to convert the dataframes into strings of normalized texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the normalized texts

# %%
def get_normalized_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "norm", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_normalized_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'5FTT5MPBHZC3HK4LCBHO5ILEQY': ('ḥꜣ.t-ꜥ m rʾ n wꜣḥ pẖr.t ḥr ꜥ.t nb.t n.t s\npri̯.n ⸗ꞽ m ꞽwn.w ḥnꜥ wr.w.PL-n.w-ḥw.t-ꜥꜣ.t.PL nb.w.PL-mk.t ḥqꜣ.w.PL-nḥḥ\nnḥm.n pri̯.n ⸗ꞽ m sꜣw ḥnꜥ mw.t-nṯr.PL\nrḏi̯.n ⸗sn n ⸗ꞽ mk.t ⸗sn\nꞽw ṯs.w.PL n ⸗ꞽ ꞽri̯.n nb-r-ḏr r dr s.t-ꜥ nṯr nṯr.t mwt mwt.t ḥmw.t-rʾ n.tꞽ m dp ⸗ꞽ pn m nḥb.t ⸗ꞽ UNK tn m qꜥḥ.w.PL ⸗ꞽ ꞽpn m ꞽwf ⸗ꞽ pn m ꜥ.t.PL ⸗ꞽ ꞽptn r sswnu̯ srḫ.y ḥr.ꞽ sꜥq.y.w.PL ẖnn m ꞽwf ⸗ꞽ pn bꞽbꞽ m ꜥ.t.PL ⸗ꞽ ꞽptn m ꜥq.t m ꞽwf ⸗ꞽ pn m dp ⸗ꞽ pn m qꜥḥ.w.PL ⸗ꞽ ꞽpn m ḥꜥ.PL ⸗ꞽ pn m ꜥ.t.PL ⸗ꞽ ꞽptn\nnꞽ wꞽ rꜥ ḏd.n ⸗f\nꞽnk nḏ ⸗ꞽ sw m-ꜥ ḫft.ꞽ.w.PL ⸗f\nsšm.w ⸗f pw ḏḥw.tꞽ\nꞽw ⸗f ḏi̯ ⸗f mdwi̯ drf\nꞽri̯ ⸗f dmḏ.t.PL\nḏi̯ ⸗f ꜣḫ n rḫ.w.PL-ꞽḫ.t.PL n swn.w.PL ꞽm.ꞽ.w.PL-ḫt.PL ⸗f r wḥꜥ mrr.w nṯr sꜥnḫ ⸗f sw\nꞽnk pw mrr.w nṯr sꜥnḫ ⸗f wꞽ\nḏd-mdw ḫft wꜣḥ pẖr.t ḥr ꜥ.t nb.t n.t s n.t.t mḥr.tꞽ\nšs-mꜣꜥ ḥḥ n zp\nky rʾ n wḥꜥ wt nb\nwḥꜥ zp-2 ꞽn ꜣs.t\nwḥꜥ ḥr.w ꞽn ꜣs.t m ḏw.t.PL ꞽri̯.yt.PL r ⸗f ꞽn sn ⸗f stḫ m smꜣm ⸗f ꞽt ⸗f ws-ꞽr\nꞽ ꜣs.t wr.t-ḥkꜣ.w wḥꜥ ⸗t wꞽ\nsfḫ ⸗t wꞽ m-ꜥ ꞽḫ.t nb.t bꞽn.t ḏw.t dšr.t m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t m-ꜥ ḏꜣ.yw ḏꜣ.yt ḏꜣi̯.tꞽ ⸗fꞽ sw ꞽm ⸗ꞽ mꞽ wḥꜥ ⸗t mꞽ sfḫ.tw ⸗t m-ꜥ sꜣ ⸗t ḥr.w ḥr-n.tt ꜥq.n ⸗ꞽ m ḫ.t pri̯.n ⸗ꞽ m mw\nnn hꜣi̯ ⸗ꞽ r ꞽꜣbt.t n.t hrw pn\nḏd.n ⸗ꞽ ḫ.kwꞽ ḫꜣ.kwꞽ\nꞽ rꜥ mdwi̯ ḥr ḏ.t ⸗k\nws-ꞽr sbḥ ḥr pri̯.t ꞽm ⸗k\nmdwi̯ rꜥ ḥr ḏ.t ⸗f\nsbḥ ws-ꞽr ḥr pri̯.t ꞽm ⸗f\nꞽsk nḥm.n ⸗k wꞽ m-ꜥ ꞽḫ.t nb.t bꞽn.t ḏw.t dšr.t m-ꜥ s.t-ꜥ nṯr s.t-ꜥ nṯr.t m-ꜥ mwt mwt.t ḥmw.t-rʾ\nšs-mꜣꜥ ḥḥ n zp\nrʾ n swrꞽ pẖr.t\nꞽyꞽ pẖr.t\nꞽyꞽ dr.t ꞽḫ.t m ꞽb ⸗ꞽ pn m ꜥ.t.PL ⸗ꞽ ꞽptn\nnḫt ḥkꜣ.PL ḥr pẖr.t ṯs-pẖr\nꞽn-ꞽw trw sḫꜣ.n ⸗k ꞽṯi̯.tw ḥr.w ḥnꜥ stḫ r ꞽz.t.PL ꜥꜣ.t n.t ꞽwn.w m nḏ.tw ẖr.wꞽ.DU stḫ ḥnꜥ ꞽr.t ḥr.w\nwn.ḫr ⸗f wꜣḏ mꞽ wnn ⸗f dp tꜣ\nꞽw ⸗f ꞽri̯ ⸗f mrr.t ⸗f nb.t mꞽ nw-n nṯr.PL n.tꞽ ꞽm\nḏd-mdw.PL ḫft swrꞽ pẖr.t\nšs-mꜣꜥ ḥḥ n zp\n',
#   375,
#   374)}

# %% [markdown]
# **Function to convert the dataframes into strings of segmented unicode texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the segmented unicode texts

# %%
def get_segmented_unicode_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "unicode_word", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_segmented_unicode_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'5FTT5MPBHZC3HK4LCBHO5ILEQY': ('𓄂𓂝 𓅓 𓂋𓏤 𓈖 𓎝𓎛\U00013455𓏛 𓄲𓂋𓏏𓈒𓏥 𓁷𓏤 𓂝𓏏𓄹 𓎟𓏏 𓈖𓏏 𓊃𓀀𓏤\n𓉐𓂋𓂻𓈖 𓀀 𓅓 𓉺𓏌𓊖 𓎛𓈖𓂝 𓀗𓏲𓅆𓏪𓏌𓏤𓉗𓉻𓏏𓉐𓅆𓏪 𓎟𓏲𓏥𓅓𓂝𓎢𓏏𓏛 𓋾𓈎𓏲𓅆𓏪𓎛𓇳𓎛\n𓈖𓈞𓅓𓂝𓈖 𓉐𓂋𓂻𓈖 𓀀 𓅓 𓊃𓅭𓄿𓏲𓊖 𓎛𓈖𓂝 𓅐𓏏𓏯𓅆𓏪𓊹𓊹𓊹𓅆𓏪\n𓂋𓂝𓈖 𓋴𓈖𓏥 𓈖 𓀀 𓅓𓂝𓎢𓏏𓏛𓏪 𓋴𓈖𓏥\n𓇋𓏲 𓋭𓊃𓏲𓀁𓏪 𓈖 𓀀 𓁹𓈖 𓎟𓂋𓇥𓂋𓅆 𓂋 𓂧𓂋𓀜 𓊨𓏏𓂝𓏤𓅪𓏥 𓊹𓅆 𓊹𓂋𓏏𓏯𓆗 𓅓𓏏𓏱 𓅓𓏏𓏏𓏱 𓍍𓏏𓏤𓏛𓏥𓂋𓏤 𓈖𓏏𓏭 𓅓 𓁶𓏤 𓀀 𓊪𓈖 𓅓 𓅘𓎛𓃀𓏏𓄹 𓀀 𓇋𓊪𓏏𓈖 UNK 𓅓 𓈎𓂝𓎛𓏲𓂢𓏥 𓀀 𓇋𓊪𓈖 𓅓 𓇋𓏲𓆑𓄹𓏥 𓀀 𓊪𓈖 𓅓 𓂝𓏏𓄹𓏥 𓀀 𓇋𓊪𓏏𓈖 𓂋 𓋴𓋴𓃹𓈖𓌕𓅪 𓋴𓂋𓐍𓇋𓇋𓀁𓏱 𓁷𓂋𓏭𓇯 𓋴𓅧𓈎𓇋𓇋𓏲𓂻𓏥 𓂙𓈖𓈖𓐎 𓅓 𓇋𓏲𓆑𓄹𓏥 𓀀 𓊪𓈖 𓃀𓇋𓃀𓇋𓀁 𓅓 𓂝𓏏𓄹𓏥 𓀀 𓇋𓊪𓏏𓈖 𓅓 𓅧𓈎𓏏𓂻 𓅓 𓇋𓏲𓆑𓄹𓏥 𓀀 𓊪𓈖 𓅓 𓁶𓏤 𓀀 𓊪𓈖 𓅓 𓈎𓂝𓎛𓏲𓂢𓏥 𓀀 𓇋𓊪𓈖 𓅓 𓎛𓂝𓄹𓏥 𓀀 UNK 𓅓 𓂝𓏏𓄹𓏥 𓀀 𓇋𓊪𓏏𓈖\n𓈖 𓅱𓀀 𓇳𓅆 𓆓𓂧𓈖 𓆑\n𓏌𓎢𓀀 𓐩𓏌𓂝 𓀀 𓇓𓏲 𓅓𓂝 𓐍𓆑𓏏𓅂𓏱𓏥 𓆑\n𓋴𓌫𓅓𓏲𓂻 𓆑 𓊪𓏲 𓅝𓏏𓏭\n𓇋𓏲 𓆑 𓂞 𓆑 𓌃𓂧𓏲𓀁 𓂧𓂋𓆑𓏯𓏛\n𓁹 𓆑 𓋬𓂧𓏏𓍼\n𓂞 𓆑 𓅜𓐍𓏛 𓈖 𓂋𓐍𓏲𓏛𓏥𓐍𓏏𓏛𓏥𓀀𓏥 𓈖 𓌕𓏌𓏤𓀀𓏥 𓏶𓅓𓏲𓏪𓆱𓐍𓏏𓂻𓀀𓏥 𓆑 𓂋 𓊠𓂝𓍢𓂝 𓌻𓂋𓂋𓏲𓀁 𓊹𓅆 𓋴𓋹𓈖𓐍 𓆑 𓇓𓏲\n𓏌𓎢𓀀 𓊪𓏲 𓌻𓂋𓂋𓏲𓀁 𓊹𓅆 𓋴𓋹𓈖𓐍 𓆑 𓏲𓀀\n𓆓𓂧𓌃𓏤𓏥 𓐍𓆑𓏏 𓎝𓎛𓏛 𓄲𓂋𓏏𓈒𓏥 𓁷𓏤 𓂝𓏏𓄹 𓎟𓏏 𓈖𓏏 𓊃𓀀𓏤 𓈖𓏏𓏏 𓍋𓅓𓂋𓅪𓍘𓇋\n𓍱𓏤𓏛𓏥𓌶𓂝𓏛 𓁨\U00013445 𓈖 𓊃𓊪𓊗\n𓎢\U00013455𓇋𓇋 𓂋𓏤 𓈖 𓊠𓂝𓍢𓂝 𓐎𓂝 𓎟\n𓊠𓂝𓍢𓂝 𓊗𓏻 𓇋𓈖 𓊨𓏏𓏯𓆗\n𓊠𓂝𓍢𓂝 𓅃𓅆 𓇋𓈖 𓆇𓏏𓏯𓅆 𓅓 𓈋𓅱𓏏𓅪𓏥 𓁹𓇋𓇋𓏏𓏥 𓂋 𓆑 𓇋𓈖 𓌢𓅆 𓆑 𓃩𓅆 𓅓 𓋴𓌳𓄿𓅓𓌪𓂝 𓆑 𓇋𓏏𓆑𓅆 𓆑 𓍟𓁹𓅆\n𓇋𓀁 𓊨𓏏𓆇𓏯𓅆 𓅨𓂋𓏏𓎛𓂓𓄿𓏲𓀁𓏪𓅆 𓊠𓂝𓍢𓂝 𓏏 𓏲𓀀\n𓋴𓆑𓐍𓍼𓏛 𓏏 𓏲𓀀 𓅓𓂝 𓐍𓏏𓏛𓏥 𓎟𓏏 𓃀𓇋𓈖𓏏𓅪 𓈋𓅱𓏏𓅪𓏥 𓂧𓈙𓂋𓏏𓏯 𓅓𓂝 𓊨𓏏𓂝𓏤𓅪𓏥 𓊹𓅆 𓊨𓏏𓂝𓏤𓅪𓏥 𓊹𓂋𓏏𓏯𓆗 𓅓𓏏 𓅓𓏏𓏱 𓅓𓏏𓏏𓏱 𓅓𓏏 𓍑𓄿𓇋𓇋𓏲𓏱 𓍑𓄿𓇋𓇋𓏏𓏱 𓍑𓄿𓏏𓏴 𓆑𓏭 𓇓𓏲 𓇋𓅓 𓀀 𓏇𓇋 𓊠𓂝𓍢𓂝 𓏏 𓏇𓇋 𓋴𓆑𓐍𓏏𓍼𓏛 𓏏 𓅓𓂝 𓅭𓅆 𓏏 𓅃𓅆 𓁷𓏤𓈖𓏏𓏏 𓅧𓈎𓂻𓈖 𓀀 𓅓 𓐍𓏏𓊮 𓉐𓂋𓂻𓈖 𓀀 𓅓 𓈗\n𓂜𓈖 𓉔𓄿𓂻 𓀀 𓂋 𓋁𓃀𓏏𓏏𓆱 𓈖𓏏 𓇳𓏤 𓊪𓈖\n𓆓𓂧𓈖 𓀀 𓐍𓏤𓀔𓎢𓏲𓀀 𓆼𓄿𓀔𓅪𓎢𓏲𓀀\n𓇋𓀁 𓇳𓅆 𓌃𓂧𓏲𓀁 𓁷𓏤 𓆓𓏏𓏤 𓎢\n𓆇𓏯𓅆 𓋴𓃀𓎛𓄑𓀁 𓁷𓏤 𓉐𓂋𓏏𓂻 𓇋𓅓 𓎢\n𓌃𓂧𓏲𓀁 𓇳𓅆 𓁷𓏤 𓆓𓏏𓏤 𓆑\n𓋴𓃀𓎛𓄑𓀁 𓍟𓁹𓅆 𓁷𓏤 𓉐𓂋𓏏𓂻 𓇋𓅓 𓆑\n𓇋𓋴𓎢 𓈖𓈞𓅓𓂝𓈖 𓎢 𓏲𓀀 𓅓𓂝 𓐍𓏏𓏛𓏥 𓎟𓏏 𓃀𓇋𓈖𓏏𓅪𓏥 𓈋𓅱𓏏𓅪𓏥 𓂧𓈙𓂋𓏏𓏯𓅪 𓅓𓂝 𓊨𓏏𓂝𓏤𓅪𓏥 𓊹𓅆 𓊨𓏏𓂝𓅪𓏥 𓊹𓂋𓏏𓏯𓆗 𓅓𓏏 𓅓𓏏𓏱 𓅓𓏏𓏏𓏱 𓍍𓏏𓏤𓏛𓏥\n𓍱𓏤𓏛𓏥𓌶𓂝𓏛 𓁨𓏤 𓈖 𓊃𓊪𓊗\n𓂋𓏤 𓈖 𓋴𓅨𓂋𓇋𓀁 𓄲𓂋𓏏𓈒𓏥\n𓇍𓏭𓂻 𓄲𓂋𓏏𓈒𓏥\n𓇍𓏭𓂻 𓂧𓂋𓏏𓂝 𓐍𓏏𓏛𓏥 𓅓 𓄣𓏤 𓀀 𓊪𓈖 𓅓 𓂝𓏏𓄹𓏥 𓀀 𓇋𓊪𓏏𓈖\n𓈖𓆱𓐍𓏏𓀜 𓎛𓂓𓄿𓀁𓏪 𓁷𓏤 𓄲𓂋𓏏𓈒𓏥 𓋭𓄲\n𓇋𓈖𓇋𓏲 𓏏𓂋𓏲𓆵𓀁 𓋴𓆼𓄿𓀁𓈖 𓎢 𓎁𓏏𓀜𓏏𓏲 𓅃𓅆 𓎛𓈖𓂝 𓃩𓅆 𓂋 𓇩𓏏𓏤𓉐𓏥 𓉻𓏏𓏛 𓈖𓏏 𓉺𓏌𓊖 𓅓 𓐩𓏌𓀁𓏏𓏲 𓌨𓂋𓏲𓏭𓄹𓄹 𓃫𓅆 𓎛𓈖𓂝 UNK 𓅃𓅆\n𓃹𓈖𓐍𓂋 𓆑 𓇆𓏛 𓏇𓇋 𓃹𓈖𓈖 UNK 𓁶𓏤 𓇾𓈇𓏤\n𓇋𓏲 𓆑 𓁹 𓆑 𓌻𓂋𓏏𓀁 𓆑 𓎟𓏏 𓏇𓇋 𓈖𓍇𓏌𓏲𓈖 𓊹𓊹𓊹𓅆𓏪 𓈖𓏏𓏭 𓇋𓅓\n𓆓𓂧𓌃𓏤𓏥 𓐍𓆑𓏏 𓋴𓅨𓂋𓇋𓈗𓀁 𓄲𓂋𓏏𓈒𓏥\n𓍱𓏤𓏛𓏥𓌶𓂝𓏛 𓁨𓏤 𓈖 𓊃𓊪𓊗\n',
#   375,
#   371)}

# %% [markdown]
# ### To create the vector space model

# %% [markdown]
# #### vectorizing texts

# %% [markdown]
# **Converts a list of texts into a term-document matrix based on TF-IDF scores**.
#
# Full documentation of the variables of TfidfVectorizer from sklearn, see: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html#sklearn.feature_extraction.text.TfidfVectorizer
# * param corpus: a dataframe in which the texts are in a `"text"` column and the dataframe's index is the text ids.
# * param analyzer: whether the feature should be made of word or character n-grams.
#                      use `"word"` for word features, `"char_wb"` for character n-grams within word boundaries,
#                      or `"char"` for character n-grams without word boundaries.
# * param ngram_range: the lower and upper boundary of the range of n-values for different n-grams to be extracted.
# * param max_df: threshold to ignore terms that have a document frequency above a certain value.
#                    If the threshold is a float, it represent a proportion of the documents.
#                    If the threshold is an integer, it represents absolute counts of number of documents in which the terms appears.
# * param min_df: threshold to ignore terms that have a document frequency below a certain value.
#                    If the threshold is a float, it represent a proportion of the documents.
#                    If the threshold is an integer, it represents absolute counts of number of documents in which the terms appears.
# * param max_features: if not `None`, build a vocabulary that only considers the top max_features ordered by term frequency across the corpus.
# * param stop_words: if `None`, no stop words are used. Otherwise, can be a list with words to be removed from resulting tokens.
# * return: `counts` the raw counts of the vectorizer,
#              `counts_df` a dataframe of the counts where the index is the text ids and the columns are the tokens,
#              `stop_words` an updated list of stop words

# %% [markdown]
# ![](https://www.humanitiesdataanalysis.org/_images/bow.png)

# %% [markdown]
# **Figure 1**. Example of a document-term matrix extracted from a corpus, see Fig. 3 in Karsdorp, F., Kestemont, M., & Riddell, A. (2021). Humanities Data Analysis: Case Studies
# with Python. Princeton University Press.

# %%
def vectorize(corpus, analyzer="word", ngram_range=(1,1), max_df=1.0, min_df=1, max_features=None, stop_words=["UNK", "X"]):

    vectorizer = TfidfVectorizer(input="content", lowercase=False, analyzer=analyzer,
                                 # RegEx for Akkadian
                                 #token_pattern=r"(?u)\b\w+\b", ngram_range=ngram_range,
                                 # RegEx for Egyptian
                                 token_pattern=r"(?u)\b[\w\.]+\b", ngram_range=ngram_range,
                                 max_df=max_df, min_df=min_df, max_features=max_features, stop_words=stop_words)

    counts = vectorizer.fit_transform(corpus["text"].tolist()).toarray()
    stop_words = vectorizer.stop_words_

    # saving the vocab used for vectorization, and switching the dictionary so that the feature index is the key
    vocab = vectorizer.vocabulary_
    switched_vocab = {value: key for key, value in vocab.items()}
    # adding the vocab words to the counts dataframe for easier viewing.
    column_names = []
    x = 0
    while x < len(switched_vocab):
        column_names.append(switched_vocab[x])
        x += 1

    counts_df = pd.DataFrame(counts, index=corpus.index, columns=column_names)

    return (counts, counts_df, stop_words)

# %% [markdown]
# #### calculating distances between vectorized documents

# %% [markdown]
# **Converts a term-document matrix to a text similarity matrix**.
# * param counts: the raw counts from the `vectorize` function.
# * param metric: the metric by which to calculate the distances between the texts in the corpus. For one place to look into the different types of matrics see "Computing distances between documents" in [Karsdrop, Kestemont, & Riddell 2021](https://www.humanitiesdataanalysis.org/vector-space-model/notebook.html#computing-distances-between-documents)
#                    Valid metrics are:
#                    ‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’,
#                    ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulczynski1’,
#                    ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’,
#                    ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’.
# * param text_ids: list of unique text_ids.
# * return: a dataframe matrix of distance between texts.

# %%
def distance_calculator(counts, metric, text_ids):

    return pd.DataFrame(squareform(pdist(counts, metric=metric)), index=text_ids, columns=text_ids)

# %% [markdown]
# #### reducing dimensions with pca or tsne

# %% [markdown]
# **Reduces multidimensional data into two dimensions using PCA**.
# * param df: dataframe holding the dimensions to reduce. All columns should include numerical values only.
#                The dataframe's index should hold the unique text ids.
# * param metadata: the rest of the metadata in the corpus, to help visualize the resulting clusters in meaningful ways.
#                      The metadata's index should hold the unique text ids.
# * return: a dataframe with the coordinates of the two remaining dimensions on all other columns from the metadata.

# %%
def reduce_dimensions_pca(df, metadata):

    pca = PCA(n_components=2)
    reduced_data = pca.fit_transform(df)
    reduced_df = pd.DataFrame(data=reduced_data, index=df.index, columns=["component 1", "component 2"])
    reduced_df_metadata = metadata.join(reduced_df)
    return reduced_df_metadata

# %% [markdown]
# **Reduces multidimensional data into two dimensions using TSNE**.
#
# See full documentation of sklearn's TSNE on: https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
# * param df: dataframe holding the dimensions to reduce. All columns should include numerical values only.
#                The dataframe's index should hold the unique text ids.
# * param perplexity: perplexity is a measure the weighs the importance of nearby versus distant points when creating a lower-dimension mapping.
#                        t-SNE first converts the distances between points into conditional probabilities that represent similarities,
#                        using Gaussian probability distributions.
#                        The perplexity parameter influences the variance used to compute these probabilities.
#                        A higher perplexity leads to a broader Gaussian that considers a larger number of neighbors when assessing similarity.
#                        Lower perplexity puts more focus on the local structure and considers fewer neighbors.
#                        A good perplexity depends greatly on dataset size and density.
#                        The documentation recommends a value between 5 and 50.
#                        We recommend to start with the square root of the length of the corpus.
# * param n_iter: maximum number of iterations for optimization.
# * param metric: the metric to be used when calculating distances between vectors.
#                    Valid metrics are:
#                    ‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’,
#                    ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulczynski1’,
#                    ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’,
#                    ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’.
# * param metadata: the rest of the metadata in the corpus, to help visualize the resulting clusters in meaningful ways.
#                      The metadata's index should hold the unique text ids.
# * return: a dataframe with the coordinates of the two remaining dimensions on all other columns from the metadata.

# %%
def reduce_dimensions_tsne(df, perplexity, n_iter, metric, metadata):

    tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, metric=metric, init="pca")
    reduced_data = tsne.fit_transform(df)
    reduced_df = pd.DataFrame(data=reduced_data, index=df.index, columns=["component 1", "component 2"])
    reduced_df_metadata = metadata.join(reduced_df)
    return reduced_df_metadata

# %% [markdown]
# ## Process texts from dataframes and combine results with metadata dataframe

# %%
# Function to combine processed texts with metadata

def get_corpus_metadata(texts_dict, metadata):
  texts_df = pd.DataFrame(texts_dict, index=["text", "full_length", "partial_length"]).transpose()
  df = metadata.join(texts_df)
  return df

# %%
## vectorize lemma forms
corpus_dict = get_lemmatized_texts(corpus, break_perc=0)
## vectorize normalized forms
# corpus_dict = get_normalized_texts(corpus, break_perc=0)
## vectorize Unicode cuneiform
# corpus_dict = get_segmented_unicode_texts(corpus, break_perc=0)

corpus_metadata = get_corpus_metadata(corpus_dict, metadata)

## For Akkadian
## remove texts which have less than n words excluding UNK and X
#n = 10
#print(f"Number of texts before filtering: {corpus_metadata.shape[0]}")
#corpus_metadata = corpus_metadata[corpus_metadata["partial_length"]>=n]
#print(f"Number of texts after filtering: {corpus_metadata.shape[0]}")


# For Egyptian use this instead, resetting the index
n = 10
print(f"Number of texts before filtering: {corpus_metadata.shape[0]}")
corpus_metadata = corpus_metadata[corpus_metadata["partial_length"]>=n].set_index("popular_name")
print(f"Number of texts after filtering: {corpus_metadata.shape[0]}")
# Out:
# Number of texts before filtering: 47
# Number of texts after filtering: 47

# %%
get_corpus_metadata(corpus_dict, metadata)
# Out:
#                                                  popular_name  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E                     pEbers_757-760
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU                     pEbers_other-1
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4                     pEbers_761-763
# 5FTT5MPBHZC3HK4LCBHO5ILEQY                         pEbers_1-3
# 5VTRLPNGTVB4NFASALVWWRA524                     pEbers_432-436
# 7GYITRCORFDG5LSMIKTYILCDJY                     pEbers_764-782
# 7RRQAVSPNFFTRNFXVC7JTPGQM4                     pEbers_284-293
# 7USDA2QTOZEKHKANKSDDZY7KXM                     pEbers_305-325
# 7YKDGDFXMVDU7FGWTYWL5VG7IA                     pEbers_451-463
# A3SCLECB6ZH23OARP74WFWLFAU                     pEbers_627-696
# AUVPRXP37FB25DEOKZEIPKBZBE                     pEbers_857-856
# B7UO6AAVTRD27PUKXLYONP4X2U                     pEbers_326-335
# BSGT2PKXWBGJLH2655FGMQVKGA                     pEbers_739-749
# DMNIC3WYUFBV7BWEBVLZFS22UE                     pEbers_482-514
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4                     pEbers_551-555
# E2YB6NH5FFEVXC6YWL5ARKMBJU                     pEbers_857-877
# EVQYPLZT3ZGT5JDAMIA7JP36EE                     pEbers_464-476
# FA35BEUTGJCLFB7EXS3WC4IKLM                     pEbers_188-220
# GCM5SJZBKBB7DOKMXH5VSA2FMA                       pEbers_4-103
# HL47O6LNQFETPLONXUSPWGNWZU                     pEbers_840-853
# J35OWBNYQFBKVLWBKP2DRLZT4A                     pEbers_592-602
# JMBIZHE2CJGYBAVGNUM6LBXSJQ                     pEbers_750-756
# JR63HPLMQRDCTITNGOF5UD64QI                     pEbers_783-807
# L4F2MBSL5VBT3PZZH43J7ZOLEA                     pEbers_221-241
# LCCCO3C7YNFPFP3CZC3MCFYNCI                     pEbers_705-725
# LPE46RS2VFCF7CJTO5CRKGDZCY                     pEbers_603-615
# LZKJPMDPJRCHTAVXRSLYBMFRXI                     pEbers_543-550
# R5GRVN4WBBHDDIQOWWCW5YZBFU                     pEbers_477-481
# REED47N2PNGD5HULYWF4VHCJPA                     pEbers_336-431
# RL7SXJKJGBHSBENWAX2KFQDGNA                     pEbers_733-738
# RQ6NFFAST5FNVMYBYI3PS2NMKA                     pEbers_515-542
# UIWX3PKRK5BLZJPCKAJSFRPWIY                     pEbers_726-732
# VHBZCYNQQJFDTGWMX34USAHENE                     pEbers_556-591
# VHKSDEIJSJEF7GWX7UIF6FBAZY                     pEbers_242-260
# VQIUBI5MUFFMXHUXJUQBIBZSOU                     pEbers_294-304
# WA6O6O6PP5CAXJVWVWHF7BKEBY                     pEbers_808-839
# WRSVQJLYRBHEDIDXVV3MQMAEKI                     pEbers_616-626
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ                     pEbers_261-283
# Y4YPWPCQUJAT3GNPZWWNMQJXVA                     pEbers_854-855
# YCZWHO3OCNGSTH74CCA3RIAGZI                     pEbers_697-704
# YQX5S6WJANF7RPBLHLXYKGAIQI                     pEbers_104-187
# Z2I5XVJGPBATVMF5WZW6MSKDLU                     pEbers_437-450
# G4RBISLJFVEMLJJZCGNLVQCCVU       pEdwinSmith_Wundenbuch_28-48
# JLNBOVGOMFGGRP7G6DT57BEW2M  pEdwinSmith_Menstruationsprobleme
# MXIKFZQQA5FEBCWBT4USMABY44        pEdwinSmith_Wundenbuch_1-27
# TQXUFUY2KRDK3DG4JWIQULW45E     pEdwinSmith_Hautverschoenerung
# VBLHGTRTIFDSFLCP7UOE7256V4      pEdwinSmith_Verjüngungsmittel
#
#                                                                       credits  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 5FTT5MPBHZC3HK4LCBHO5ILEQY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 5VTRLPNGTVB4NFASALVWWRA524  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 7GYITRCORFDG5LSMIKTYILCDJY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 7RRQAVSPNFFTRNFXVC7JTPGQM4  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 7USDA2QTOZEKHKANKSDDZY7KXM  Lutz Popko, unter Mitarbeit von Altägyptisches...
# 7YKDGDFXMVDU7FGWTYWL5VG7IA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# A3SCLECB6ZH23OARP74WFWLFAU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# AUVPRXP37FB25DEOKZEIPKBZBE  Lutz Popko, unter Mitarbeit von Altägyptisches...
# B7UO6AAVTRD27PUKXLYONP4X2U  Lutz Popko, unter Mitarbeit von Altägyptisches...
# BSGT2PKXWBGJLH2655FGMQVKGA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# DMNIC3WYUFBV7BWEBVLZFS22UE  Lutz Popko, unter Mitarbeit von Altägyptisches...
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4  Lutz Popko, unter Mitarbeit von Altägyptisches...
# E2YB6NH5FFEVXC6YWL5ARKMBJU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# EVQYPLZT3ZGT5JDAMIA7JP36EE  Lutz Popko, unter Mitarbeit von Altägyptisches...
# FA35BEUTGJCLFB7EXS3WC4IKLM  Lutz Popko, unter Mitarbeit von Altägyptisches...
# GCM5SJZBKBB7DOKMXH5VSA2FMA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# HL47O6LNQFETPLONXUSPWGNWZU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# J35OWBNYQFBKVLWBKP2DRLZT4A  Lutz Popko, unter Mitarbeit von Altägyptisches...
# JMBIZHE2CJGYBAVGNUM6LBXSJQ  Lutz Popko, unter Mitarbeit von Altägyptisches...
# JR63HPLMQRDCTITNGOF5UD64QI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# L4F2MBSL5VBT3PZZH43J7ZOLEA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# LCCCO3C7YNFPFP3CZC3MCFYNCI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# LPE46RS2VFCF7CJTO5CRKGDZCY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# LZKJPMDPJRCHTAVXRSLYBMFRXI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# R5GRVN4WBBHDDIQOWWCW5YZBFU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# REED47N2PNGD5HULYWF4VHCJPA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# RL7SXJKJGBHSBENWAX2KFQDGNA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# RQ6NFFAST5FNVMYBYI3PS2NMKA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# UIWX3PKRK5BLZJPCKAJSFRPWIY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# VHBZCYNQQJFDTGWMX34USAHENE  Lutz Popko, unter Mitarbeit von Altägyptisches...
# VHKSDEIJSJEF7GWX7UIF6FBAZY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# VQIUBI5MUFFMXHUXJUQBIBZSOU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# WA6O6O6PP5CAXJVWVWHF7BKEBY  Lutz Popko, unter Mitarbeit von Altägyptisches...
# WRSVQJLYRBHEDIDXVV3MQMAEKI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ  Lutz Popko, unter Mitarbeit von Altägyptisches...
# Y4YPWPCQUJAT3GNPZWWNMQJXVA  Lutz Popko, unter Mitarbeit von Altägyptisches...
# YCZWHO3OCNGSTH74CCA3RIAGZI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# YQX5S6WJANF7RPBLHLXYKGAIQI  Lutz Popko, unter Mitarbeit von Altägyptisches...
# Z2I5XVJGPBATVMF5WZW6MSKDLU  Lutz Popko, unter Mitarbeit von Altägyptisches...
# G4RBISLJFVEMLJJZCGNLVQCCVU  Peter Dils, unter Mitarbeit von Altägyptisches...
# JLNBOVGOMFGGRP7G6DT57BEW2M  Peter Dils, unter Mitarbeit von Altägyptisches...
# MXIKFZQQA5FEBCWBT4USMABY44  Peter Dils, unter Mitarbeit von Altägyptisches...
# TQXUFUY2KRDK3DG4JWIQULW45E  Peter Dils, unter Mitarbeit von Altägyptisches...
# VBLHGTRTIFDSFLCP7UOE7256V4  Peter Dils, unter Mitarbeit von Altägyptisches...
#
#                            script_type                   period  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E    hieratic  16th c. BCE (18th dyn.)
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU    hieratic  16th c. BCE (18th dyn.)
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4    hieratic  16th c. BCE (18th dyn.)
# 5FTT5MPBHZC3HK4LCBHO5ILEQY    hieratic  16th c. BCE (18th dyn.)
# 5VTRLPNGTVB4NFASALVWWRA524    hieratic  16th c. BCE (18th dyn.)
# 7GYITRCORFDG5LSMIKTYILCDJY    hieratic  16th c. BCE (18th dyn.)
# 7RRQAVSPNFFTRNFXVC7JTPGQM4    hieratic  16th c. BCE (18th dyn.)
# 7USDA2QTOZEKHKANKSDDZY7KXM    hieratic  16th c. BCE (18th dyn.)
# 7YKDGDFXMVDU7FGWTYWL5VG7IA    hieratic  16th c. BCE (18th dyn.)
# A3SCLECB6ZH23OARP74WFWLFAU    hieratic  16th c. BCE (18th dyn.)
# AUVPRXP37FB25DEOKZEIPKBZBE    hieratic  16th c. BCE (18th dyn.)
# B7UO6AAVTRD27PUKXLYONP4X2U    hieratic  16th c. BCE (18th dyn.)
# BSGT2PKXWBGJLH2655FGMQVKGA    hieratic  16th c. BCE (18th dyn.)
# DMNIC3WYUFBV7BWEBVLZFS22UE    hieratic  16th c. BCE (18th dyn.)
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4    hieratic  16th c. BCE (18th dyn.)
# E2YB6NH5FFEVXC6YWL5ARKMBJU    hieratic  16th c. BCE (18th dyn.)
# EVQYPLZT3ZGT5JDAMIA7JP36EE    hieratic  16th c. BCE (18th dyn.)
# FA35BEUTGJCLFB7EXS3WC4IKLM    hieratic  16th c. BCE (18th dyn.)
# GCM5SJZBKBB7DOKMXH5VSA2FMA    hieratic  16th c. BCE (18th dyn.)
# HL47O6LNQFETPLONXUSPWGNWZU    hieratic  16th c. BCE (18th dyn.)
# J35OWBNYQFBKVLWBKP2DRLZT4A    hieratic  16th c. BCE (18th dyn.)
# JMBIZHE2CJGYBAVGNUM6LBXSJQ    hieratic  16th c. BCE (18th dyn.)
# JR63HPLMQRDCTITNGOF5UD64QI    hieratic  16th c. BCE (18th dyn.)
# L4F2MBSL5VBT3PZZH43J7ZOLEA    hieratic  16th c. BCE (18th dyn.)
# LCCCO3C7YNFPFP3CZC3MCFYNCI    hieratic  16th c. BCE (18th dyn.)
# LPE46RS2VFCF7CJTO5CRKGDZCY    hieratic  16th c. BCE (18th dyn.)
# LZKJPMDPJRCHTAVXRSLYBMFRXI    hieratic  16th c. BCE (18th dyn.)
# R5GRVN4WBBHDDIQOWWCW5YZBFU    hieratic  16th c. BCE (18th dyn.)
# REED47N2PNGD5HULYWF4VHCJPA    hieratic  16th c. BCE (18th dyn.)
# RL7SXJKJGBHSBENWAX2KFQDGNA    hieratic  16th c. BCE (18th dyn.)
# RQ6NFFAST5FNVMYBYI3PS2NMKA    hieratic  16th c. BCE (18th dyn.)
# UIWX3PKRK5BLZJPCKAJSFRPWIY    hieratic  16th c. BCE (18th dyn.)
# VHBZCYNQQJFDTGWMX34USAHENE    hieratic  16th c. BCE (18th dyn.)
# VHKSDEIJSJEF7GWX7UIF6FBAZY    hieratic  16th c. BCE (18th dyn.)
# VQIUBI5MUFFMXHUXJUQBIBZSOU    hieratic  16th c. BCE (18th dyn.)
# WA6O6O6PP5CAXJVWVWHF7BKEBY    hieratic  16th c. BCE (18th dyn.)
# WRSVQJLYRBHEDIDXVV3MQMAEKI    hieratic  16th c. BCE (18th dyn.)
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ    hieratic  16th c. BCE (18th dyn.)
# Y4YPWPCQUJAT3GNPZWWNMQJXVA    hieratic  16th c. BCE (18th dyn.)
# YCZWHO3OCNGSTH74CCA3RIAGZI    hieratic  16th c. BCE (18th dyn.)
# YQX5S6WJANF7RPBLHLXYKGAIQI    hieratic  16th c. BCE (18th dyn.)
# Z2I5XVJGPBATVMF5WZW6MSKDLU    hieratic  16th c. BCE (18th dyn.)
# G4RBISLJFVEMLJJZCGNLVQCCVU    hieratic  16th c. BCE (17th dyn.)
# JLNBOVGOMFGGRP7G6DT57BEW2M    hieratic  16th c. BCE (17th dyn.)
# MXIKFZQQA5FEBCWBT4USMABY44    hieratic  16th c. BCE (17th dyn.)
# TQXUFUY2KRDK3DG4JWIQULW45E    hieratic  16th c. BCE (17th dyn.)
# VBLHGTRTIFDSFLCP7UOE7256V4    hieratic  16th c. BCE (17th dyn.)
#
#                                                                    collection  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 5FTT5MPBHZC3HK4LCBHO5ILEQY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 5VTRLPNGTVB4NFASALVWWRA524  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 7GYITRCORFDG5LSMIKTYILCDJY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 7RRQAVSPNFFTRNFXVC7JTPGQM4  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 7USDA2QTOZEKHKANKSDDZY7KXM  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# 7YKDGDFXMVDU7FGWTYWL5VG7IA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# A3SCLECB6ZH23OARP74WFWLFAU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# AUVPRXP37FB25DEOKZEIPKBZBE  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# B7UO6AAVTRD27PUKXLYONP4X2U  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# BSGT2PKXWBGJLH2655FGMQVKGA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# DMNIC3WYUFBV7BWEBVLZFS22UE  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# E2YB6NH5FFEVXC6YWL5ARKMBJU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# EVQYPLZT3ZGT5JDAMIA7JP36EE  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# FA35BEUTGJCLFB7EXS3WC4IKLM  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# GCM5SJZBKBB7DOKMXH5VSA2FMA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# HL47O6LNQFETPLONXUSPWGNWZU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# J35OWBNYQFBKVLWBKP2DRLZT4A  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# JMBIZHE2CJGYBAVGNUM6LBXSJQ  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# JR63HPLMQRDCTITNGOF5UD64QI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# L4F2MBSL5VBT3PZZH43J7ZOLEA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# LCCCO3C7YNFPFP3CZC3MCFYNCI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# LPE46RS2VFCF7CJTO5CRKGDZCY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# LZKJPMDPJRCHTAVXRSLYBMFRXI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# R5GRVN4WBBHDDIQOWWCW5YZBFU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# REED47N2PNGD5HULYWF4VHCJPA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# RL7SXJKJGBHSBENWAX2KFQDGNA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# RQ6NFFAST5FNVMYBYI3PS2NMKA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# UIWX3PKRK5BLZJPCKAJSFRPWIY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# VHBZCYNQQJFDTGWMX34USAHENE  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# VHKSDEIJSJEF7GWX7UIF6FBAZY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# VQIUBI5MUFFMXHUXJUQBIBZSOU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# WA6O6O6PP5CAXJVWVWHF7BKEBY  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# WRSVQJLYRBHEDIDXVV3MQMAEKI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# Y4YPWPCQUJAT3GNPZWWNMQJXVA  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# YCZWHO3OCNGSTH74CCA3RIAGZI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# YQX5S6WJANF7RPBLHLXYKGAIQI  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# Z2I5XVJGPBATVMF5WZW6MSKDLU  Bibliotheca Albertina, Papyrus- und Ostrakasam...
# G4RBISLJFVEMLJJZCGNLVQCCVU  Academy of Medicine, New York, USA, URI: http:...
# JLNBOVGOMFGGRP7G6DT57BEW2M  Academy of Medicine, New York, USA, URI: http:...
# MXIKFZQQA5FEBCWBT4USMABY44  Academy of Medicine, New York, USA, URI: http:...
# TQXUFUY2KRDK3DG4JWIQULW45E  Academy of Medicine, New York, USA, URI: http:...
# VBLHGTRTIFDSFLCP7UOE7256V4  Academy of Medicine, New York, USA, URI: http:...
#
#                                 project  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E       pEbers
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU       pEbers
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4       pEbers
# 5FTT5MPBHZC3HK4LCBHO5ILEQY       pEbers
# 5VTRLPNGTVB4NFASALVWWRA524       pEbers
# 7GYITRCORFDG5LSMIKTYILCDJY       pEbers
# 7RRQAVSPNFFTRNFXVC7JTPGQM4       pEbers
# 7USDA2QTOZEKHKANKSDDZY7KXM       pEbers
# 7YKDGDFXMVDU7FGWTYWL5VG7IA       pEbers
# A3SCLECB6ZH23OARP74WFWLFAU       pEbers
# AUVPRXP37FB25DEOKZEIPKBZBE       pEbers
# B7UO6AAVTRD27PUKXLYONP4X2U       pEbers
# BSGT2PKXWBGJLH2655FGMQVKGA       pEbers
# DMNIC3WYUFBV7BWEBVLZFS22UE       pEbers
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4       pEbers
# E2YB6NH5FFEVXC6YWL5ARKMBJU       pEbers
# EVQYPLZT3ZGT5JDAMIA7JP36EE       pEbers
# FA35BEUTGJCLFB7EXS3WC4IKLM       pEbers
# GCM5SJZBKBB7DOKMXH5VSA2FMA       pEbers
# HL47O6LNQFETPLONXUSPWGNWZU       pEbers
# J35OWBNYQFBKVLWBKP2DRLZT4A       pEbers
# JMBIZHE2CJGYBAVGNUM6LBXSJQ       pEbers
# JR63HPLMQRDCTITNGOF5UD64QI       pEbers
# L4F2MBSL5VBT3PZZH43J7ZOLEA       pEbers
# LCCCO3C7YNFPFP3CZC3MCFYNCI       pEbers
# LPE46RS2VFCF7CJTO5CRKGDZCY       pEbers
# LZKJPMDPJRCHTAVXRSLYBMFRXI       pEbers
# R5GRVN4WBBHDDIQOWWCW5YZBFU       pEbers
# REED47N2PNGD5HULYWF4VHCJPA       pEbers
# RL7SXJKJGBHSBENWAX2KFQDGNA       pEbers
# RQ6NFFAST5FNVMYBYI3PS2NMKA       pEbers
# UIWX3PKRK5BLZJPCKAJSFRPWIY       pEbers
# VHBZCYNQQJFDTGWMX34USAHENE       pEbers
# VHKSDEIJSJEF7GWX7UIF6FBAZY       pEbers
# VQIUBI5MUFFMXHUXJUQBIBZSOU       pEbers
# WA6O6O6PP5CAXJVWVWHF7BKEBY       pEbers
# WRSVQJLYRBHEDIDXVV3MQMAEKI       pEbers
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ       pEbers
# Y4YPWPCQUJAT3GNPZWWNMQJXVA       pEbers
# YCZWHO3OCNGSTH74CCA3RIAGZI       pEbers
# YQX5S6WJANF7RPBLHLXYKGAIQI       pEbers
# Z2I5XVJGPBATVMF5WZW6MSKDLU       pEbers
# G4RBISLJFVEMLJJZCGNLVQCCVU  pEdwinSmith
# JLNBOVGOMFGGRP7G6DT57BEW2M  pEdwinSmith
# MXIKFZQQA5FEBCWBT4USMABY44  pEdwinSmith
# TQXUFUY2KRDK3DG4JWIQULW45E  pEdwinSmith
# VBLHGTRTIFDSFLCP7UOE7256V4  pEdwinSmith
#
#                                                                          text  \
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ srwḫ gs wnm.ꞽ m rwy.t\nꜣḥ w...
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU  rnp.t-zp 1...n ḫr ḥm n.ꞽ nswt-bꞽ.tꞽ Ḏsr-kꜣ-Rꜥw...
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ rš\nbnꞽ.w\nmḥ rʾ ⸗f ꞽm\nky ...
# 5FTT5MPBHZC3HK4LCBHO5ILEQY  ḥꜣ.t-ꜥ m rʾ n.ꞽ X pẖr.t ḥr ꜥ.t nb n.ꞽ z\npri̯ ...
# 5VTRLPNGTVB4NFASALVWWRA524  ky n.ꞽ pzḥ n.ꞽ rmṯ\nẖꜥꜥ n.ꞽ šḏ.t n.tꞽ m ꜥnḏ.w ...
# 7GYITRCORFDG5LSMIKTYILCDJY  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ msḏr nḏs sḏm ⸗f\nmnš.t ḏrḏ ...
# 7RRQAVSPNFFTRNFXVC7JTPGQM4  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ rḏi̯ šzp ꞽb tʾ\nꞽwf ḏdꜣ 1.....
# 7USDA2QTOZEKHKANKSDDZY7KXM  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr sry.t\nḏꜣr.t wꜣḏ\nrḏi̯ ḥ...
# 7YKDGDFXMVDU7FGWTYWL5VG7IA  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr skm srwḫ šnꞽ\nznf n.ꞽ bḥ...
# A3SCLECB6ZH23OARP74WFWLFAU  ḥꜣ.t-ꜥ m nwd.t n.ꞽ smn mt\npẖr.t n.ꞽ snḏm mt\n...
# AUVPRXP37FB25DEOKZEIPKBZBE  ḥꜣ.t-ꜥ m mḏꜣ.t n.ꞽ hbhb wḫd.w m ꜥ.t nb n.ꞽ z m...
# B7UO6AAVTRD27PUKXLYONP4X2U  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ smꜣ gḥ.w\nꞽnnk 1...n+++1/+2...
# BSGT2PKXWBGJLH2655FGMQVKGA  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ smn ꞽbḥ\nꞽri̯ m ꞽḫ.t wꜥ\nwš...
# DMNIC3WYUFBV7BWEBVLZFS22UE  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ wbd.t\nꞽri̯ r ⸗s hrw tp.ꞽ\n...
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr bn.wt m ḥꜥ.w n.ꞽ z m ꜥ.t...
# E2YB6NH5FFEVXC6YWL5ARKMBJU  šsꜣ.w ḥnḥn.t m ḥty.t n.ꞽ z\nꞽr wpi̯ ⸗k nn m ḥt...
# EVQYPLZT3ZGT5JDAMIA7JP36EE  sꜣr qnqn 1...n ḥr mrḥ.t 1...n\nrḏi̯ ḥr mw n.ꞽ ...
# FA35BEUTGJCLFB7EXS3WC4IKLM  šsꜣ.w n.ꞽ mn rʾ-ꞽb\nꞽr ḫꜣi̯ ⸗k z ḥr šnꜥ n.ꞽ rʾ...
# GCM5SJZBKBB7DOKMXH5VSA2FMA  ḥꜣ.t-ꜥ m dmḏ.t n.ꞽ pẖr.t dr mr.t m ẖ.t\ntḥwꜣ\n...
# HL47O6LNQFETPLONXUSPWGNWZU  ḥꜣ.t-ꜥ m pẖr.t\nꞽri̯ r dr py m pr\nntš ⸗k sw m...
# J35OWBNYQFBKVLWBKP2DRLZT4A  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ wnm-znf sgr wšꜥ.w\npsi̯ m ꞽ...
# JMBIZHE2CJGYBAVGNUM6LBXSJQ  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr dḥr.t-zb.t\nzwr m srf n....
# JR63HPLMQRDCTITNGOF5UD64QI  ḥꜣ.t-ꜥ m pẖr.t ꞽri̯ n ḥm.t\nrḏi̯ ꜣb z.t ꞽwr m ...
# L4F2MBSL5VBT3PZZH43J7ZOLEA  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr ꜥꜣꜥ m ẖ.t m ḥꜣ.tꞽ\npr.t ...
# LCCCO3C7YNFPFP3CZC3MCFYNCI  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr špn mr ḥꜥ.w n.ꞽ z z.t rʾ...
# LPE46RS2VFCF7CJTO5CRKGDZCY  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ sgnn mꜣs.t\nnḏ m ꞽḫ.t wꜥ\nw...
# LZKJPMDPJRCHTAVXRSLYBMFRXI  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr ꜣk.wt\nbnꞽ.w 1...n bd.t-...
# R5GRVN4WBBHDDIQOWWCW5YZBFU  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ srwḫ mꞽz.t\ndꜣb 1...n+++1/+...
# REED47N2PNGD5HULYWF4VHCJPA  ky ḥꜣ.t-ꜥ m dmḏ.t n.ꞽ ꞽr.t\nꞽri̯ r rd.t n.ꞽ wḫ...
# RL7SXJKJGBHSBENWAX2KFQDGNA  pẖr.t n.ꞽ dr ḥmw.t-zꜣ\nḫprr ꜥꜣ\nšꜥ ḏꜣḏꜣ ⸗f ḏnḥ...
# RQ6NFFAST5FNVMYBYI3PS2NMKA  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ ssnb wbn.w wdi̯ ḥr ḥꜥ.w\nkꜣ...
# UIWX3PKRK5BLZJPCKAJSFRPWIY  ꞽri̯ r šdi̯ sr.t ꞽw ⸗s m ḥꜥ.w\npr bꞽbꞽ bꞽ.t\nr...
# VHBZCYNQQJFDTGWMX34USAHENE  ḥꜣ.t-ꜥ m dr šf.wt sgr wšꜥ.w m ꜥ.t nb n.ꞽ z\nns...
# VHKSDEIJSJEF7GWX7UIF6FBAZY  ḥꜣ.t-ꜥ m pẖr.t ꞽri̯ Rꜥw ḥr ⸗f ḏs ⸗f\nbꞽ.t ꞽm.w...
# VQIUBI5MUFFMXHUXJUQBIBZSOU  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ shꜣi̯ st.t m npḥ.w\nsm.w\ns...
# WA6O6O6PP5CAXJVWVWHF7BKEBY  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ tm rḏi̯ hꜣi̯ bn.tꞽ\nbꜥbꜥ ⸗s...
# WRSVQJLYRBHEDIDXVV3MQMAEKI  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ ḏbꜥ mr ⸗f sꜣḥ rʾ-pw\nꞽr-m-ḫ...
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr ṯꜣz.t-n.t-mw.yt mr kns\n...
# Y4YPWPCQUJAT3GNPZWWNMQJXVA  ḥꜣ.t-ꜥ m sštꜣ n.ꞽ zwn.w rḫ šm.t ḥꜣ.tꞽ rḫ ḥꜣ.tꞽ...
# YCZWHO3OCNGSTH74CCA3RIAGZI  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr mr.t ns\nꞽrṯ.t\nẖpꜥ\nrḏi...
# YQX5S6WJANF7RPBLHLXYKGAIQI  ḥꜣ.t-ꜥ m gs.w n.ꞽ dr wḥꜣ\nꞽnr-spd.w ꞽrṯ.t mrḥ....
# Z2I5XVJGPBATVMF5WZW6MSKDLU  ḥꜣ.t-ꜥ m pẖr.t n.ꞽ dr ḫnsy.t m tp\npr.t dgm 1....
# G4RBISLJFVEMLJJZCGNLVQCCVU  šsꜣ.w wbn.w m ḫꜥm ⸗f\nꞽr ḫꜣi̯ ⸗k z n.ꞽ wbn.w n...
# JLNBOVGOMFGGRP7G6DT57BEW2M  ꞽr mꜣꜣ ⸗k z ḥr mn pḥ.wꞽ ⸗fꞽ ꜥḥꜥ ⸗f ḥmsi̯ ⸗f ḥr...
# MXIKFZQQA5FEBCWBT4USMABY44  UNK\nwt ⸗k sw ḥr ꞽwf X X X\nX ⸗k sw X m mrḥ.t ...
# TQXUFUY2KRDK3DG4JWIQULW45E  pẖr.t spnꜥ+(ꞽnm) ꞽnm\nbꞽ.t 1...n ḥzmn dšr 1......
# VBLHGTRTIFDSFLCP7UOE7256V4  ḥꜣ.t-ꜥ m mḏꜣ.t n.ꞽ ꞽri̯ ꞽꜣw m rnp\nꞽni̯ ⸗tw ḥm...
#
#                            full_length partial_length
# Unnamed: 0
# 2SQY75KWF5HUXBJCDHOUZPKT3E          99             99
# 3RU7Z4VQ45CYFIQ4PUGQ3HDJFU          93             93
# 4QZJJ2HEGBGDTIKGGBXB2L2NA4          93             93
# 5FTT5MPBHZC3HK4LCBHO5ILEQY         375            372
# 5VTRLPNGTVB4NFASALVWWRA524         116            116
# 7GYITRCORFDG5LSMIKTYILCDJY         569            567
# 7RRQAVSPNFFTRNFXVC7JTPGQM4         172            170
# 7USDA2QTOZEKHKANKSDDZY7KXM         541            541
# 7YKDGDFXMVDU7FGWTYWL5VG7IA         228            227
# A3SCLECB6ZH23OARP74WFWLFAU        1615           1615
# AUVPRXP37FB25DEOKZEIPKBZBE         309            309
# B7UO6AAVTRD27PUKXLYONP4X2U         162            159
# BSGT2PKXWBGJLH2655FGMQVKGA         183            183
# DMNIC3WYUFBV7BWEBVLZFS22UE         681            681
# DR5Y6A4RDVE7JAVB5FMTEOCQZ4          93             93
# E2YB6NH5FFEVXC6YWL5ARKMBJU        1661           1660
# EVQYPLZT3ZGT5JDAMIA7JP36EE         260            260
# FA35BEUTGJCLFB7EXS3WC4IKLM        2263           2260
# GCM5SJZBKBB7DOKMXH5VSA2FMA        2244           2243
# HL47O6LNQFETPLONXUSPWGNWZU         257            257
# J35OWBNYQFBKVLWBKP2DRLZT4A         210            210
# JMBIZHE2CJGYBAVGNUM6LBXSJQ         133            133
# JR63HPLMQRDCTITNGOF5UD64QI         462            462
# L4F2MBSL5VBT3PZZH43J7ZOLEA         452            452
# LCCCO3C7YNFPFP3CZC3MCFYNCI         421            421
# LPE46RS2VFCF7CJTO5CRKGDZCY         341            341
# LZKJPMDPJRCHTAVXRSLYBMFRXI         122            122
# R5GRVN4WBBHDDIQOWWCW5YZBFU         116            116
# REED47N2PNGD5HULYWF4VHCJPA        2254           2254
# RL7SXJKJGBHSBENWAX2KFQDGNA         122            122
# RQ6NFFAST5FNVMYBYI3PS2NMKA         601            601
# UIWX3PKRK5BLZJPCKAJSFRPWIY         106            106
# VHBZCYNQQJFDTGWMX34USAHENE         727            727
# VHKSDEIJSJEF7GWX7UIF6FBAZY         673            673
# VQIUBI5MUFFMXHUXJUQBIBZSOU         338            338
# WA6O6O6PP5CAXJVWVWHF7BKEBY         791            791
# WRSVQJLYRBHEDIDXVV3MQMAEKI         292            292
# X2UCZ7EIYNFVJEOGMUNRKY2OFQ         561            559
# Y4YPWPCQUJAT3GNPZWWNMQJXVA         950            950
# YCZWHO3OCNGSTH74CCA3RIAGZI         100            100
# YQX5S6WJANF7RPBLHLXYKGAIQI        1853           1852
# Z2I5XVJGPBATVMF5WZW6MSKDLU         181            181
# G4RBISLJFVEMLJJZCGNLVQCCVU        2538           2537
# JLNBOVGOMFGGRP7G6DT57BEW2M          48             48
# MXIKFZQQA5FEBCWBT4USMABY44        3905           3678
# TQXUFUY2KRDK3DG4JWIQULW45E          38             38
# VBLHGTRTIFDSFLCP7UOE7256V4         276            276

# %% [markdown]
# # Exploring the RINAP Corpus using the Vector Space Model

# %%
# vectorize corpus
counts, counts_df, stop_words = vectorize(corpus_metadata, max_features=200)

# %%
counts_df.head(3)
# Out:
#                       1     1...n   16         2     2...1   32       64  \
# popular_name
# pEbers_757-760  0.56861  0.360432  0.0  0.000000  0.514457  0.0  0.06492
# pEbers_other-1  0.00000  0.661201  0.0  0.000000  0.000000  0.0  0.00000
# pEbers_761-763  0.00000  0.110962  0.0  0.103672  0.000000  0.0  0.00000
#
#                        _       bnꞽ  bꜣq  ...     ꞽrṯ.t        ꞽt   ꞽw  ꞽwf  \
# popular_name                             ...
# pEbers_757-760  0.291715  0.000000  0.0  ...  0.000000  0.035448  0.0  0.0
# pEbers_other-1  0.447379  0.000000  0.0  ...  0.000000  0.000000  0.0  0.0
# pEbers_761-763  0.000000  0.089885  0.0  ...  0.179769  0.000000  0.0  0.0
#
#                 ꞽwi  ꞽšd   ꞽḥ     ꞽḫ.t  ꞽꜣd.t  ꞽꜥr
# popular_name
# pEbers_757-760  0.0  0.0  0.0  0.01897    0.0  0.0
# pEbers_other-1  0.0  0.0  0.0  0.00000    0.0  0.0
# pEbers_761-763  0.0  0.0  0.0  0.00000    0.0  0.0
#
# [3 rows x 200 columns]

# %%
# calculate distance between vectorized texts
matrix = distance_calculator(counts, "cosine", corpus_metadata.index)

# %%
# visualize matrix
fig = px.imshow(matrix)

# adjust size of the matrix
fig.update_layout(
    autosize=False,
    width=1000,
    height=1000,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2be88476-d4cc-4306-9c77-f05d1d45fcbb" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2be88476-d4cc-4306-9c77-f05d1d45fcbb")) {                    Plotly.newPlot(                        "2be88476-d4cc-4306-9c77-f05d1d45fcbb",                        [{"coloraxis":"coloraxis","name":"0","x":["pEbers_757-760","pEbers_other-1","pEbers_761-763","pEbers_1-3","pEbers_432-436","pEbers_764-782","pEbers_284-293","pEbers_305-325","pEbers_451-463","pEbers_627-696","pEbers_857-856","pEbers_326-335","pEbers_739-749","pEbers_482-514","pEbers_551-555","pEbers_857-877","pEbers_464-476","pEbers_188-220","pEbers_4-103","pEbers_840-853","pEbers_592-602","pEbers_750-756","pEbers_783-807","pEbers_221-241","pEbers_705-725","pEbers_603-615","pEbers_543-550","pEbers_477-481","pEbers_336-431","pEbers_733-738","pEbers_515-542","pEbers_726-732","pEbers_556-591","pEbers_242-260","pEbers_294-304","pEbers_808-839","pEbers_616-626","pEbers_261-283","pEbers_854-855","pEbers_697-704","pEbers_104-187","pEbers_437-450","pEdwinSmith_Wundenbuch_28-48","pEdwinSmith_Menstruationsprobleme","pEdwinSmith_Wundenbuch_1-27","pEdwinSmith_Hautverschoenerung","pEdwinSmith_Verj\u00fcngungsmittel"],"y":["pEbers_757-760","pEbers_other-1","pEbers_761-763","pEbers_1-3","pEbers_432-436","pEbers_764-782","pEbers_284-293","pEbers_305-325","pEbers_451-463","pEbers_627-696","pEbers_857-856","pEbers_326-335","pEbers_739-749","pEbers_482-514","pEbers_551-555","pEbers_857-877","pEbers_464-476","pEbers_188-220","pEbers_4-103","pEbers_840-853","pEbers_592-602","pEbers_750-756","pEbers_783-807","pEbers_221-241","pEbers_705-725","pEbers_603-615","pEbers_543-550","pEbers_477-481","pEbers_336-431","pEbers_733-738","pEbers_515-542","pEbers_726-732","pEbers_556-591","pEbers_242-260","pEbers_294-304","pEbers_808-839","pEbers_616-626","pEbers_261-283","pEbers_854-855","pEbers_697-704","pEbers_104-187","pEbers_437-450","pEdwinSmith_Wundenbuch_28-48","pEdwinSmith_Menstruationsprobleme","pEdwinSmith_Wundenbuch_1-27","pEdwinSmith_Hautverschoenerung","pEdwinSmith_Verj\u00fcngungsmittel"],"z":[[0.0,0.622790367932831,0.8816759526152678,0.9350836178348957,0.8012415528251146,0.6380445315648301,0.12062348827747038,0.47224961881436944,0.9093636787287318,0.5598757104419617,0.7946467129935249,0.16029274069699184,0.4813424818152662,0.6501290313142494,0.44703059012006086,0.8814560908998557,0.7444632194158058,0.49611605947180804,0.16784917518417897,0.8924779323956088,0.45985963717483125,0.23356829756739983,0.6176087792207456,0.08457488141494807,0.5658415600700006,0.663284631217194,0.654195588891644,0.09752530716433228,0.5702808030766389,0.9126474974964705,0.6751364448907824,0.806796241761573,0.5825055021008084,0.6584107952677429,0.31394202717650577,0.5775069057204724,0.31795954528283144,0.18756550068233535,0.8437464937825911,0.6999488365244231,0.23895687689899892,0.6705996564174804,0.9101239372335203,0.9247486712048079,0.9091933265071258,0.7054755069603265,0.891761325971367],[0.622790367932831,0.0,0.9072550062576813,0.9530143284952208,0.6511361383190175,0.7919160939611039,0.7143649114431725,0.6653486145128672,0.9642690767869571,0.5233986502919161,0.8606340423128453,0.693418825845765,0.5343038159629545,0.5247568875296167,0.4433753098220429,0.9456927166262487,0.6366458834969837,0.7628330529809633,0.6556990669553078,0.9658787569998067,0.6790296427869775,0.5963141943402256,0.6632442578543538,0.7543901781834118,0.7256205455127175,0.5638074922814651,0.4356885437595345,0.7243387722697274,0.6016806550306774,0.9831164292834407,0.5566302471984439,0.8156080992308065,0.579189107541702,0.5129340330370673,0.6493108850956909,0.7052321542432887,0.5441904894352563,0.615112758766708,0.8924600615953788,0.5797612692239245 ...

# %%
# reduce matrix dimensions
reduced_tsne = reduce_dimensions_tsne(matrix, perplexity=matrix.shape[0]**0.5, n_iter=5000, metric="euclidean", metadata=corpus_metadata)

# %%
# visualize reduced dimensions

# adjust size column for visualization
size_min = 3
size_max = 70
size = (reduced_tsne["partial_length"] / reduced_tsne["partial_length"].max() * (size_max - size_min) + size_min).tolist()

# create figure
# for Akkadian use symbol = "script"
# for Egyptian delete that parameter or switch to symbol = 'script_type'
fig = px.scatter(reduced_tsne, x="component 1", y="component 2", size=size, color="project", symbol="script_type", hover_data=["partial_length", "full_length", reduced_tsne.index])
fig.update_traces(marker=dict(line=dict(width=1, color='black')))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1f10d701-b98d-49aa-a041-b5731b097b29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f10d701-b98d-49aa-a041-b5731b097b29")) {                    Plotly.newPlot(                        "1f10d701-b98d-49aa-a041-b5731b097b29",                        [{"customdata":[[99,99,"pEbers_757-760"],[93,93,"pEbers_other-1"],[93,93,"pEbers_761-763"],[372,375,"pEbers_1-3"],[116,116,"pEbers_432-436"],[567,569,"pEbers_764-782"],[170,172,"pEbers_284-293"],[541,541,"pEbers_305-325"],[227,228,"pEbers_451-463"],[1615,1615,"pEbers_627-696"],[309,309,"pEbers_857-856"],[159,162,"pEbers_326-335"],[183,183,"pEbers_739-749"],[681,681,"pEbers_482-514"],[93,93,"pEbers_551-555"],[1660,1661,"pEbers_857-877"],[260,260,"pEbers_464-476"],[2260,2263,"pEbers_188-220"],[2243,2244,"pEbers_4-103"],[257,257,"pEbers_840-853"],[210,210,"pEbers_592-602"],[133,133,"pEbers_750-756"],[462,462,"pEbers_783-807"],[452,452,"pEbers_221-241"],[421,421,"pEbers_705-725"],[341,341,"pEbers_603-615"],[122,122,"pEbers_543-550"],[116,116,"pEbers_477-481"],[2254,2254,"pEbers_336-431"],[122,122,"pEbers_733-738"],[601,601,"pEbers_515-542"],[106,106,"pEbers_726-732"],[727,727,"pEbers_556-591"],[673,673,"pEbers_242-260"],[338,338,"pEbers_294-304"],[791,791,"pEbers_808-839"],[292,292,"pEbers_616-626"],[559,561,"pEbers_261-283"],[950,950,"pEbers_854-855"],[100,100,"pEbers_697-704"],[1852,1853,"pEbers_104-187"],[181,181,"pEbers_437-450"]],"hovertemplate":"project=pEbers\u003cbr\u003escript_type=hieratic\u003cbr\u003ecomponent 1=%{x}\u003cbr\u003ecomponent 2=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003epartial_length=%{customdata[0]}\u003cbr\u003efull_length=%{customdata[1]}\u003cbr\u003epopular_name=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pEbers, hieratic","marker":{"color":"#636efa","size":[4.803425774877651,4.694127243066884,4.694127243066884,9.776508972267536,5.11310494834149,13.328711256117455,6.096791734638391,12.855084284937467,7.135127786840674,32.41952147906471,8.628874388254486,5.896411092985318,6.333605220228385,15.405383360522023,4.694127243066884,33.239260467645465,7.736269711799891,44.16911364872213,43.85943447525829,7.6816204458945085,6.825448613376835,5.4227841218053285,11.415986949429037,11.233822729744427,10.669113648722131,9.211799891245242,5.2224034801522565,5.11310494834149,44.05981511691136,5.2224034801522565,13.948069603045134,4.9309407286568785,16.243338771071237,15.259651984774333,9.15715062533986,17.409189777052745,8.319195214790646,13.182979880369766,20.305600870038067,4.821642196846112,36.73681348559,6.297172376291463],"sizemode":"area","sizeref":0.175,"symbol":"circle","line":{"color":"black","width":1}},"mode":"markers","name":"pEbers, hieratic","orientation":"v","showlegend":true,"x":[14.411178588867188,-7.377600193023682,13.286259651184082,16.081951141357422,16.42506217956543,1.0514174699783325,12.630718231201172,0.6383513808250427,8.571864128112793,-14.86396312713623,13.162471771240234,11.06139850616455,-13.092692375183105,-5.3944549560546875,-9.196645736694336,13.971378326416016,-3.826092481613159,1.6296697854995728,8.995841026306152,10.01203441619873,-4.679363250732422,-10.73624038696289,-6.777040958404541,14.548409461975098,-5.319297790527344,-15.485100746154785,-7.780786037445068,13.166379928588867,-1.9010450839996338,9.891838073730469,-6.09277868270874,-6.415740013122559,-3.9893970489501953,-4.414090156555176,2.0887668132781982,-6.924033164978027,-10.276494026184082,8.002960205078125,14.376211166381836,-13.369990348815918,6.281475067138672,-5.931059837341309],"xaxis":"x","y":[9.19094467163086,22.26624298095703,-23.13691520690918,-17.447269439697266,-22.91766929626465,-0.20409424602985382,10.847447395324707,7 ...

# %% [markdown]
# # Find Shared Tokens

# %% [markdown]
# **creates a mini df that includes only the chosen text and the shared tokens in those texts**
#   (i.e., all tokens that are none zero in all texts).
# * param df: the counts_df where the index is the text ids and the columns are the tokens.
# * param text_ids: a list containing text ids.
# * return: a dataframe where the index are the shared tokens and the columns are the texts.
#            the values are the tf-idf scores.

# %%
def find_shared_tokens(df, text_ids):

  mini_df = df[df.index.isin(text_ids)].copy()
  mini_df = mini_df.loc[:, (mini_df != 0).all(axis=0)].copy()
  return mini_df.transpose()

# %%
# Akkadian
#shared_tokens = find_shared_tokens(counts_df, ["Q003450", "Q003711", "Q003790"])
# Egyptian
shared_tokens = find_shared_tokens(counts_df, ["pEdwinSmith_Wundenbuch_1-27", "pEdwinSmith_Wundenbuch_28-48", "pEdwinSmith_Hautverschoenerung", "pEbers_432-436"])#, "3RU7Z4VQ45CYFIQ4PUGQ3HDJFU"])

shared_tokens
# Out:
# popular_name  pEbers_432-436  pEdwinSmith_Wundenbuch_28-48  \
# bꞽ.t                0.041768                      0.023721
# m                   0.252499                      0.263158
# n.ꞽ                 0.247292                      0.174394
# pẖr.t               0.076803                      0.001678
# wꜥ                  0.085326                      0.009319
# ḥr                  0.274495                      0.118202
# ꞽḫ.t                0.081792                      0.019652
#
# popular_name  pEdwinSmith_Wundenbuch_1-27  pEdwinSmith_Hautverschoenerung
# bꞽ.t                             0.019329                        0.197175
# m                                0.253520                        0.170280
# n.ꞽ                              0.148158                        0.083385
# pẖr.t                            0.003332                        0.090640
# wꜥ                               0.002468                        0.201397
# ḥr                               0.091868                        0.092557
# ꞽḫ.t                             0.035485                        0.193057

# %%
px.scatter(shared_tokens)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f4c03c9d-810c-4fc9-ad9f-5d98d50290c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4c03c9d-810c-4fc9-ad9f-5d98d50290c7")) {                    Plotly.newPlot(                        "f4c03c9d-810c-4fc9-ad9f-5d98d50290c7",                        [{"hovertemplate":"popular_name=pEbers_432-436\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pEbers_432-436","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"pEbers_432-436","orientation":"v","showlegend":true,"x":["b\ua7bd.t","m","n.\ua7bd","p\u1e96r.t","w\ua725","\u1e25r","\ua7bd\u1e2b.t"],"xaxis":"x","y":[0.04176845010576696,0.2524987613787089,0.24729241301596447,0.07680276182616336,0.08532572930545104,0.274494799827432,0.08179224428263639],"yaxis":"y","type":"scatter"},{"hovertemplate":"popular_name=pEdwinSmith_Wundenbuch_28-48\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pEdwinSmith_Wundenbuch_28-48","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"pEdwinSmith_Wundenbuch_28-48","orientation":"v","showlegend":true,"x":["b\ua7bd.t","m","n.\ua7bd","p\u1e96r.t","w\ua725","\u1e25r","\ua7bd\u1e2b.t"],"xaxis":"x","y":[0.023720890234851816,0.26315822867063127,0.17439356955979265,0.0016775910989851946,0.009318784936486664,0.1182018961490129,0.019652331697870493],"yaxis":"y","type":"scatter"},{"hovertemplate":"popular_name=pEdwinSmith_Wundenbuch_1-27\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pEdwinSmith_Wundenbuch_1-27","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"pEdwinSmith_Wundenbuch_1-27","orientation":"v","showlegend":true,"x":["b\ua7bd.t","m","n.\ua7bd","p\u1e96r.t","w\ua725","\u1e25r","\ua7bd\u1e2b.t"],"xaxis":"x","y":[0.019329186869743584,0.2535202926068586,0.14815830346699715,0.0033320640302918893,0.0024678868894552667,0.09186844005535201,0.035485311810515986],"yaxis":"y","type":"scatter"},{"hovertemplate":"popular_name=pEdwinSmith_Hautverschoenerung\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pEdwinSmith_Hautverschoenerung","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"pEdwinSmith_Hautverschoenerung","orientation":"v","showlegend":true,"x":["b\ua7bd.t","m","n.\ua7bd","p\u1e96r.t","w\ua725","\u1e25r","\ua7bd\u1e2b.t"],"xaxis":"x","y":[0.19717493071687853,0.1702803556781471,0.08338464675022438,0.09064005968375526,0.2013971636673986,0.09255703253987961,0.19305696116050194],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333 ...

# %% [markdown]
# *This notebook was created by [Avital Romach](https://github.com/ARomach), with additional code and text by [Eliese-Sophia Lincke](https://www.berliner-antike-kolleg.org/en/bak/team/fda/eliese-sophia_lincke/index.html) and [Shai Gordin](https://digitalpasts.github.io/) in Spring 2024 for the course [Ancient Language Processing](https://digitalpasts.github.io/ALP-course/). Code can be reused under a [CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/)*
